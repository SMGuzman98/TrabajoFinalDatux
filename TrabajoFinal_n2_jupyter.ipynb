# %% [markdown]
# # Trabajo final Datux Python - Filtrado de DataFrames y Series

# %% [markdown]
# ## Ejercicio - Búsqueda de alojamiento en Airbnb

# %%
import pandas as pd
df_airbnb=pd.read_csv('C:/Users/moseb/Documents/Datux/Python/TrabajoFinal_Datux_Python/FinalPython/src/pandas/airbnb.csv', sep=',')

# %%
df_airbnb.head()
# Out:
#    room_id  host_id        room_type       neighborhood  reviews  \
# 0     6499    14455  Entire home/apt              Belém        8
# 1    17031    66015  Entire home/apt           Alvalade        0
# 2    25659   107347  Entire home/apt  Santa Maria Maior       63
# 3    29248   125768  Entire home/apt  Santa Maria Maior      225
# 4    29396   126415  Entire home/apt  Santa Maria Maior      132
#
#    overall_satisfaction  accommodates  bedrooms  price
# 0                   5.0             2       1.0   57.0
# 1                   0.0             2       1.0   46.0
# 2                   5.0             3       1.0   69.0
# 3                   4.5             4       1.0   58.0
# 4                   5.0             4       1.0   67.0

# %%
df_airbnb.dtypes
# Out:
# room_id                   int64
# host_id                   int64
# room_type                object
# neighborhood             object
# reviews                   int64
# overall_satisfaction    float64
# accommodates              int64
# bedrooms                float64
# price                   float64
# dtype: object

# %% [markdown]
# ## Usando Pandas

# %% [markdown]
# ### Caso 1

# %%
condicion1=(df_airbnb.room_type=="Private room") & (df_airbnb.reviews>10) & (df_airbnb.overall_satisfaction>4)
df_airbnb[condicion1]
# Out:
#         room_id    host_id     room_type       neighborhood  reviews  \
# 41        90387     490050  Private room      Santo António      204
# 54       108058     557442  Private room           Alvalade       24
# 60       120697     607028  Private room  Santa Maria Maior      138
# 65       125536     624049  Private room  Santa Maria Maior      170
# 68       126646     628095  Private room    Penha de França       98
# ...         ...        ...           ...                ...      ...
# 11792  18159125   51018503  Private room            Arroios       13
# 11866  18213011  125742566  Private room        São Vicente       12
# 11901  18250550  126119082  Private room       Misericórdia       11
# 11994  18311057  126613630  Private room  Santa Maria Maior       11
# 12012  18322425  106306229  Private room    Penha de França       14
#
#        overall_satisfaction  accommodates  bedrooms  price
# 41                      5.0             2       1.0   46.0
# 54                      5.0             1       1.0   27.0
# 60                      5.0             2       1.0   42.0
# 65                      4.5             2       1.0   40.0
# 68                      4.5             3       1.0   31.0
# ...                     ...           ...       ...    ...
# 11792                   4.5             2       1.0   21.0
# 11866                   5.0             2       1.0   30.0
# 11901                   5.0             1       1.0   31.0
# 11994                   5.0             1       1.0   23.0
# 12012                   4.5             2       2.0   31.0
#
# [1023 rows x 9 columns]

# %%
df_sorted=df_airbnb[condicion1].sort_values(by=["overall_satisfaction", "reviews"], ascending=[False, False])
df_sorted.head(3)
# Out:
#      room_id  host_id     room_type       neighborhood  reviews  \
# 786   876537  4544870  Private room      Santo António      253
# 955  1113994  6108352  Private room  Santa Maria Maior      225
# 41     90387   490050  Private room      Santo António      204
#
#      overall_satisfaction  accommodates  bedrooms  price
# 786                   5.0             2       1.0   31.0
# 955                   5.0             2       1.0   46.0
# 41                    5.0             2       1.0   46.0

# %% [markdown]
# ### Caso 2

# %%
condicion2=(df_airbnb.room_id==97503) | (df_airbnb.room_id==90387)
df_airbnb[condicion2]
# Out:
#     room_id  host_id     room_type   neighborhood  reviews  \
# 41    90387   490050  Private room  Santo António      204
# 48    97503   515924  Private room  Santo António       39
#
#     overall_satisfaction  accommodates  bedrooms  price
# 41                   5.0             2       1.0   46.0
# 48                   4.0             2       1.0   26.0

# %%
df_airbnb[condicion2].to_excel('C:/Users/moseb/Documents/Datux/Python/TrabajoFinal_Datux_Python/FinalPython/src/pandas/roberto.xlsx',
sheet_name='data', encoding='utf-8', index=False)

# %% [markdown]
# ### Caso 3

# %%
condicion3=(df_airbnb.room_type=="Shared room") & (df_airbnb.price<=16.67)
df_airbnb[condicion3]
# Out:
#         room_id    host_id    room_type       neighborhood  reviews  \
# 1010    1179457    5799522  Shared room      Santo António       42
# 2838    4010418   12771657  Shared room       Misericórdia       12
# 3562    5557699   28812904  Shared room  Santa Maria Maior       22
# 3597    5610245   29084261  Shared room  Santa Maria Maior        8
# 3738    5823046   29676067  Shared room       Misericórdia       35
# 4319    6691321   28812904  Shared room  Santa Maria Maior        1
# 4353    6728244   28812904  Shared room  Santa Maria Maior        8
# 4354    6728398   28812904  Shared room  Santa Maria Maior        3
# 4921    7737202   40574313  Shared room     Avenidas Novas       44
# 5616    9317561   48360716  Shared room            Arroios       13
# 6056   10397682   32344156  Shared room       Misericórdia       15
# 6058   10398958   32344156  Shared room       Misericórdia       39
# 6282   11014997   32344156  Shared room       Misericórdia       32
# 6284   11015580   32344156  Shared room       Misericórdia       15
# 6639   11693115   28812904  Shared room  Santa Maria Maior        5
# 6640   11693356   28812904  Shared room  Santa Maria Maior        3
# 6641   11693442   28812904  Shared room  Santa Maria Maior       16
# 6894   12041448   64460695  Shared room            Estrela        1
# 6920   12070663   64460695  Shared room            Estrela        5
# 7034   12268067   66077974  Shared room            Arroios       96
# 7059   12299979   66077974  Shared room            Arroios       13
# 7060   12299998   66077974  Shared room            Arroios       49
# 7066   12305540   66077974  Shared room            Arroios       40
# 7584   13116032   72951043  Shared room            Arroios        1
# 7643   13190640   73826302  Shared room            Arroios       51
# 7661   13219674   73826302  Shared room            Arroios       17
# 7662   13220202   73826302  Shared room            Arroios       22
# 7904   13520423   77663975  Shared room  Santa Maria Maior        7
# 7920   13556777   77905788  Shared room            Arroios        1
# 8385   14068386   84472028  Shared room        São Vicente       17
# 8897   14702408   40574313  Shared room     Avenidas Novas       14
# 8908   14708916   91501272  Shared room      Santo António       18
# 8918   14719962   40574313  Shared room     Avenidas Novas        4
# 9061   14932515   91501272  Shared room      Santo António        9
# 9062   14932518   91501272  Shared room      Santo António        7
# 9063   14933037   91501272  Shared room      Santo António        0
# 9065   14933182   91501272  Shared room      Santo António        5
# 9523   15537505   48360716  Shared room            Arroios        2
# 9796   15880914  101182323  Shared room              Belém        7
# 9964   16150682   58899339  Shared room     Avenidas Novas        4
# 10559  16875711  112226564  Shared room            Olivais       15
# 10723  17096560  107813252  Shared room            Areeiro        5
# 10954  17378961  117425901  Shared room            Arroios        0
# 11730  18095471  124601372  Shared room      Santo António        5
# 11787  18154042  124601372  Shared room     Avenidas Novas        1
# 11789  18154378  124601372  Shared room      Santo António        4
# 12042  18347196  107813252  Shared room            Areeiro        0
# 12043  18347279  107813252  Shared room            Areeiro        0
# 12044  18347626  107813252  Shared room            Areeiro        2
# 13148  19314160  135270245  Shared room        Santa Clara        0
#
#        overall_satisfaction  accommodates  bedrooms  price
# 1010                    4.0            16       1.0   10.0
# 2838                    4.5             6       1.0   15.0
# 3562                    4.0             1       1.0   10.0
# 3597                    4.0             4       1.0   11.0
# 3738                    4.5            12       1.0   15.0
# 4319                    0.0             1       1.0   11.0
# 4353                    4.5             1       1.0   11.0
# 4354                    2.5             1       1.0   11.0
# 4921                    4.5             4       1.0   13.0
# 5616                    4.5             4       1.0   11.0
# 6056                    5.0             8       1.0   13.0
# 6058                    4.5             8       1.0   12.0
# 6282                    4.5             2       1.0   16.0
# 6284                    4.5             8       1.0   15.0
# 6639                    3.5             1       1.0   11.0
# 6640                    4.5             1       1.0   11.0
# 6641                    4.5             1       1.0   11.0
# 6894                    0.0             6       1.0   15.0
# 6920                    4.5             7       1.0   13.0
# 7034                    5.0             1       1.0   16.0
# 7059                    4.5             1       1.0   16.0
# 7060                    5.0             1       1.0   13.0
# 7066                    5.0             1       1.0   13.0
# 7584                    0.0             8       1.0   10.0
# 7643                    4.5             6       1.0   13.0
# 7661                    4.5             4       1.0   13.0
# 7662                    4.5             3       1.0   13.0
# 7904                    4.5            10       1.0   15.0
# 7920                    0.0             7       1.0   15.0
# 8385                    4.5             1       1.0   12.0
# 8897                    4.5             4       1.0   13.0
# 8908                    4.5             4       1.0   11.0
# 8918                    5.0             4       1.0   13.0
# 9061                    4.5             4       1.0   11.0
# 9062                    4.5             4       1.0   11.0
# 9063                    0.0             8       1.0   11.0
# 9065                    5.0             8       1.0   11.0
# 9523                    0.0             4       1.0   15.0
# 9796                    4.5             8       1.0   16.0
# 9964                    5.0             9       1.0   16.0
# 10559                   4.0             1       1.0   15.0
# 10723                   5.0             1       1.0   16.0
# 10954                   0.0            10       1.0   16.0
# 11730                   4.0            16       1.0   11.0
# 11787                   0.0             6       1.0   11.0
# 11789                   4.5             4       1.0   11.0
# 12042                   0.0             1       1.0   16.0
# 12043                   0.0             1       1.0   16.0
# 12044                   0.0             1       1.0   16.0
# 13148                   0.0             1       1.0   10.0

# %%
df_sorted=df_airbnb[condicion3].sort_values(by=["price", "overall_satisfaction"], ascending=[True, False])
df_sorted.head(10)
# Out:
#         room_id    host_id    room_type       neighborhood  reviews  \
# 1010    1179457    5799522  Shared room      Santo António       42
# 3562    5557699   28812904  Shared room  Santa Maria Maior       22
# 7584   13116032   72951043  Shared room            Arroios        1
# 13148  19314160  135270245  Shared room        Santa Clara        0
# 9065   14933182   91501272  Shared room      Santo António        5
# 4353    6728244   28812904  Shared room  Santa Maria Maior        8
# 5616    9317561   48360716  Shared room            Arroios       13
# 6640   11693356   28812904  Shared room  Santa Maria Maior        3
# 6641   11693442   28812904  Shared room  Santa Maria Maior       16
# 8908   14708916   91501272  Shared room      Santo António       18
#
#        overall_satisfaction  accommodates  bedrooms  price
# 1010                    4.0            16       1.0   10.0
# 3562                    4.0             1       1.0   10.0
# 7584                    0.0             8       1.0   10.0
# 13148                   0.0             1       1.0   10.0
# 9065                    5.0             8       1.0   11.0
# 4353                    4.5             1       1.0   11.0
# 5616                    4.5             4       1.0   11.0
# 6640                    4.5             1       1.0   11.0
# 6641                    4.5             1       1.0   11.0
# 8908                    4.5             4       1.0   11.0

# %% [markdown]
# ## Usando MatPlot

# %% [markdown]
# ### Caso 1

# %% [markdown]
# #### Realizar un gráfico circular, de la cantidad de tipo de habitaciones room_type

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_airbnb=pd.read_csv('C:/Users/moseb/Documents/Datux/Python/TrabajoFinal_Datux_Python/FinalPython/src/pandas/airbnb.csv', sep=',')
tipo_cuarto=df_airbnb[['room_type']]
gr=tipo_cuarto.value_counts().plot.pie()
